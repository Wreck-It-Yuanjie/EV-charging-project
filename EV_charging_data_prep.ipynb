# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("EVcharging_daily_data.csv")

# %%
df.head()
# Out:
#     StartDate                 Station Name  Energy (kWh)  Fee
# 0  2016-08-01     PALO ALTO CA / BRYANT #1     65.935780  0.0
# 1  2016-08-01     PALO ALTO CA / BRYANT #2     62.881228  0.0
# 2  2016-08-01     PALO ALTO CA / BRYANT #3     38.870160  0.0
# 3  2016-08-01  PALO ALTO CA / CAMBRIDGE #1     86.989137  0.0
# 4  2016-08-01  PALO ALTO CA / CAMBRIDGE #2     74.735361  0.0

# %%
df["StartDate"] = pd.to_datetime(df["StartDate"]).dt.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37892 entries, 0 to 37891
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   StartDate     37892 non-null  object
#  1   Station Name  37892 non-null  object
#  2   Energy (kWh)  37892 non-null  float64
#  3   Fee           37892 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Univariate data prep

# %%
df_univariate = df.loc[df["Station Name"] == "PALO ALTO CA / BRYANT #1", ["Energy (kWh)"]]

# %%
df_univariate = df_univariate.iloc[0:700, :]

# %%
plt.plot(df_univariate["Energy (kWh)"])

# %%
df_univariate.to_csv("EVcharging_data_univariate_p.csv")
