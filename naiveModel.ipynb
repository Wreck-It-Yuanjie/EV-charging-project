# %%
from math import sqrt
from numpy import mean
from numpy import median
from multiprocessing import cpu_count
from joblib import Parallel
from joblib import delayed
from warnings import catch_warnings
from warnings import filterwarnings
from sklearn.metrics import mean_squared_error
from pandas import read_csv

# %%
# one-step simple forecast
def simple_forecast(history, config):
    n, offset, avg_type = config
    # persist value, ignore other config
    if avg_type == 'persist':
        return history[-n]
    # collect values to average
    values = list()
    if offset == 1:
        values = history[-n:]
    else:
        # skip bad configs
        if n*offset > len(history):
            raise Exception('Config beyond end of data: %d %d' % (n,offset))
        # try and collect n values using offset
        for i in range(1, n+1):
            ix = i * offset
            values.append(history[-ix])
    # check if we can average
    if len(values) < 2:
        raise Exception('Cannot calculate average')
    # mean of last n values
    if avg_type == 'mean':
        return mean(values)
    # median of last n values
    return median(values)

# %%
# root mean squared error or rmse
def measure_rmse(actual, predicted):
    return sqrt(mean_squared_error(actual, predicted))

# %%
# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test], data[-n_test:]

# %%
# walk-forward validation for univariate data
def walk_forward_validation(data, n_test, cfg):
    predictions = list()
    # split dataset
    train, test = train_test_split(data, n_test)
    # seed history with training dataset
    history = [x for x in train]
    # step over each time-step in the test set
    for i in range(len(test)):
        # fit model and make forecast for history
        yhat = simple_forecast(history, cfg)
        # store forecast in list of predictions
        predictions.append(yhat)
        # add actual observation to history for the next loop
        history.append(test[i])
    # estimate prediction error
    error = measure_rmse(test, predictions)
    return error

# %%
# score a model, return None on failure
def score_model(data, n_test, cfg, debug=False):
    result = None
    # convert config to a key
    key = str(cfg)
    # show all warnings and fail on exception if debugging
    if debug:
        result = walk_forward_validation(data, n_test, cfg)
    else:
        # one failure during model validation suggests an unstable config
        try:
            # never show warnings when grid searching, too noisy
            with catch_warnings():
                filterwarnings("ignore")
                result = walk_forward_validation(data, n_test, cfg)
        except:
            error = None
    # check for an interesting result
    if result is not None:
        print(' > Model[%s] %.3f' % (key, result))
    return (key, result)

# %%
# grid search configs
def grid_search(data, cfg_list, n_test, parallel=True):
    scores = [score_model(data, n_test, cfg) for cfg in cfg_list]
    # remove empty results
    scores = [r for r in scores if r[1] != None]
    # sort configs by error, asc
    scores.sort(key=lambda tup: tup[1])
    return scores

# %%
# create a set of simple configs to try
def simple_configs(max_length, offsets=[1]):
    configs = list()
    for i in range(1, max_length+1):
        for o in offsets:
            for t in ['persist', 'mean', 'median']:
                cfg = [i, o, t]
                configs.append(cfg)
    return configs

# %%
# define dataset
series = read_csv('daily-total-female-births.csv', header=0, index_col=0)
data = series.values

# %%
# data split
n_test = 165

# model configs
max_length = len(data) - n_test
cfg_list = simple_configs(max_length)

# %%
cfg_list
# Out:
# [[1, 1, 'persist'],
#  [1, 1, 'mean'],
#  [1, 1, 'median'],
#  [2, 1, 'persist'],
#  [2, 1, 'mean'],
#  [2, 1, 'median'],
#  [3, 1, 'persist'],
#  [3, 1, 'mean'],
#  [3, 1, 'median'],
#  [4, 1, 'persist'],
#  [4, 1, 'mean'],
#  [4, 1, 'median'],
#  [5, 1, 'persist'],
#  [5, 1, 'mean'],
#  [5, 1, 'median'],
#  [6, 1, 'persist'],
#  [6, 1, 'mean'],
#  [6, 1, 'median'],
#  [7, 1, 'persist'],
#  [7, 1, 'mean'],
#  [7, 1, 'median'],
#  [8, 1, 'persist'],
#  [8, 1, 'mean'],
#  [8, 1, 'median'],
#  [9, 1, 'persist'],
#  [9, 1, 'mean'],
#  [9, 1, 'median'],
#  [10, 1, 'persist'],
#  [10, 1, 'mean'],
#  [10, 1, 'median'],
#  [11, 1, 'persist'],
#  [11, 1, 'mean'],
#  [11, 1, 'median'],
#  [12, 1, 'persist'],
#  [12, 1, 'mean'],
#  [12, 1, 'median'],
#  [13, 1, 'persist'],
#  [13, 1, 'mean'],
#  [13, 1, 'median'],
#  [14, 1, 'persist'],
#  [14, 1, 'mean'],
#  [14, 1, 'median'],
#  [15, 1, 'persist'],
#  [15, 1, 'mean'],
#  [15, 1, 'median'],
#  [16, 1, 'persist'],
#  [16, 1, 'mean'],
#  [16, 1, 'median'],
#  [17, 1, 'persist'],
#  [17, 1, 'mean'],
#  [17, 1, 'median'],
#  [18, 1, 'persist'],
#  [18, 1, 'mean'],
#  [18, 1, 'median'],
#  [19, 1, 'persist'],
#  [19, 1, 'mean'],
#  [19, 1, 'median'],
#  [20, 1, 'persist'],
#  [20, 1, 'mean'],
#  [20, 1, 'median'],
#  [21, 1, 'persist'],
#  [21, 1, 'mean'],
#  [21, 1, 'median'],
#  [22, 1, 'persist'],
#  [22, 1, 'mean'],
#  [22, 1, 'median'],
#  [23, 1, 'persist'],
#  [23, 1, 'mean'],
#  [23, 1, 'median'],
#  [24, 1, 'persist'],
#  [24, 1, 'mean'],
#  [24, 1, 'median'],
#  [25, 1, 'persist'],
#  [25, 1, 'mean'],
#  [25, 1, 'median'],
#  [26, 1, 'persist'],
#  [26, 1, 'mean'],
#  [26, 1, 'median'],
#  [27, 1, 'persist'],
#  [27, 1, 'mean'],
#  [27, 1, 'median'],
#  [28, 1, 'persist'],
#  [28, 1, 'mean'],
#  [28, 1, 'median'],
#  [29, 1, 'persist'],
#  [29, 1, 'mean'],
#  [29, 1, 'median'],
#  [30, 1, 'persist'],
#  [30, 1, 'mean'],
#  [30, 1, 'median'],
#  [31, 1, 'persist'],
#  [31, 1, 'mean'],
#  [31, 1, 'median'],
#  [32, 1, 'persist'],
#  [32, 1, 'mean'],
#  [32, 1, 'median'],
#  [33, 1, 'persist'],
#  [33, 1, 'mean'],
#  [33, 1, 'median'],
#  [34, 1, 'persist'],
#  [34, 1, 'mean'],
#  [34, 1, 'median'],
#  [35, 1, 'persist'],
#  [35, 1, 'mean'],
#  [35, 1, 'median'],
#  [36, 1, 'persist'],
#  [36, 1, 'mean'],
#  [36, 1, 'median'],
#  [37, 1, 'persist'],
#  [37, 1, 'mean'],
#  [37, 1, 'median'],
#  [38, 1, 'persist'],
#  [38, 1, 'mean'],
#  [38, 1, 'median'],
#  [39, 1, 'persist'],
#  [39, 1, 'mean'],
#  [39, 1, 'median'],
#  [40, 1, 'persist'],
#  [40, 1, 'mean'],
#  [40, 1, 'median'],
#  [41, 1, 'persist'],
#  [41, 1, 'mean'],
#  [41, 1, 'median'],
#  [42, 1, 'persist'],
#  [42, 1, 'mean'],
#  [42, 1, 'median'],
#  [43, 1, 'persist'],
#  [43, 1, 'mean'],
#  [43, 1, 'median'],
#  [44, 1, 'persist'],
#  [44, 1, 'mean'],
#  [44, 1, 'median'],
#  [45, 1, 'persist'],
#  [45, 1, 'mean'],
#  [45, 1, 'median'],
#  [46, 1, 'persist'],
#  [46, 1, 'mean'],
#  [46, 1, 'median'],
#  [47, 1, 'persist'],
#  [47, 1, 'mean'],
#  [47, 1, 'median'],
#  [48, 1, 'persist'],
#  [48, 1, 'mean'],
#  [48, 1, 'median'],
#  [49, 1, 'persist'],
#  [49, 1, 'mean'],
#  [49, 1, 'median'],
#  [50, 1, 'persist'],
#  [50, 1, 'mean'],
#  [50, 1, 'median'],
#  [51, 1, 'persist'],
#  [51, 1, 'mean'],
#  [51, 1, 'median'],
#  [52, 1, 'persist'],
#  [52, 1, 'mean'],
#  [52, 1, 'median'],
#  [53, 1, 'persist'],
#  [53, 1, 'mean'],
#  [53, 1, 'median'],
#  [54, 1, 'persist'],
#  [54, 1, 'mean'],
#  [54, 1, 'median'],
#  [55, 1, 'persist'],
#  [55, 1, 'mean'],
#  [55, 1, 'median'],
#  [56, 1, 'persist'],
#  [56, 1, 'mean'],
#  [56, 1, 'median'],
#  [57, 1, 'persist'],
#  [57, 1, 'mean'],
#  [57, 1, 'median'],
#  [58, 1, 'persist'],
#  [58, 1, 'mean'],
#  [58, 1, 'median'],
#  [59, 1, 'persist'],
#  [59, 1, 'mean'],
#  [59, 1, 'median'],
#  [60, 1, 'persist'],
#  [60, 1, 'mean'],
#  [60, 1, 'median'],
#  [61, 1, 'persist'],
#  [61, 1, 'mean'],
#  [61, 1, 'median'],
#  [62, 1, 'persist'],
#  [62, 1, 'mean'],
#  [62, 1, 'median'],
#  [63, 1, 'persist'],
#  [63, 1, 'mean'],
#  [63, 1, 'median'],
#  [64, 1, 'persist'],
#  [64, 1, 'mean'],
#  [64, 1, 'median'],
#  [65, 1, 'persist'],
#  [65, 1, 'mean'],
#  [65, 1, 'median'],
#  [66, 1, 'persist'],
#  [66, 1, 'mean'],
#  [66, 1, 'median'],
#  [67, 1, 'persist'],
#  [67, 1, 'mean'],
#  [67, 1, 'median'],
#  [68, 1, 'persist'],
#  [68, 1, 'mean'],
#  [68, 1, 'median'],
#  [69, 1, 'persist'],
#  [69, 1, 'mean'],
#  [69, 1, 'median'],
#  [70, 1, 'persist'],
#  [70, 1, 'mean'],
#  [70, 1, 'median'],
#  [71, 1, 'persist'],
#  [71, 1, 'mean'],
#  [71, 1, 'median'],
#  [72, 1, 'persist'],
#  [72, 1, 'mean'],
#  [72, 1, 'median'],
#  [73, 1, 'persist'],
#  [73, 1, 'mean'],
#  [73, 1, 'median'],
#  [74, 1, 'persist'],
#  [74, 1, 'mean'],
#  [74, 1, 'median'],
#  [75, 1, 'persist'],
#  [75, 1, 'mean'],
#  [75, 1, 'median'],
#  [76, 1, 'persist'],
#  [76, 1, 'mean'],
#  [76, 1, 'median'],
#  [77, 1, 'persist'],
#  [77, 1, 'mean'],
#  [77, 1, 'median'],
#  [78, 1, 'persist'],
#  [78, 1, 'mean'],
#  [78, 1, 'median'],
#  [79, 1, 'persist'],
#  [79, 1, 'mean'],
#  [79, 1, 'median'],
#  [80, 1, 'persist'],
#  [80, 1, 'mean'],
#  [80, 1, 'median'],
#  [81, 1, 'persist'],
#  [81, 1, 'mean'],
#  [81, 1, 'median'],
#  [82, 1, 'persist'],
#  [82, 1, 'mean'],
#  [82, 1, 'median'],
#  [83, 1, 'persist'],
#  [83, 1, 'mean'],
#  [83, 1, 'median'],
#  [84, 1, 'persist'],
#  [84, 1, 'mean'],
#  [84, 1, 'median'],
#  [85, 1, 'persist'],
#  [85, 1, 'mean'],
#  [85, 1, 'median'],
#  [86, 1, 'persist'],
#  [86, 1, 'mean'],
#  [86, 1, 'median'],
#  [87, 1, 'persist'],
#  [87, 1, 'mean'],
#  [87, 1, 'median'],
#  [88, 1, 'persist'],
#  [88, 1, 'mean'],
#  [88, 1, 'median'],
#  [89, 1, 'persist'],
#  [89, 1, 'mean'],
#  [89, 1, 'median'],
#  [90, 1, 'persist'],
#  [90, 1, 'mean'],
#  [90, 1, 'median'],
#  [91, 1, 'persist'],
#  [91, 1, 'mean'],
#  [91, 1, 'median'],
#  [92, 1, 'persist'],
#  [92, 1, 'mean'],
#  [92, 1, 'median'],
#  [93, 1, 'persist'],
#  [93, 1, 'mean'],
#  [93, 1, 'median'],
#  [94, 1, 'persist'],
#  [94, 1, 'mean'],
#  [94, 1, 'median'],
#  [95, 1, 'persist'],
#  [95, 1, 'mean'],
#  [95, 1, 'median'],
#  [96, 1, 'persist'],
#  [96, 1, 'mean'],
#  [96, 1, 'median'],
#  [97, 1, 'persist'],
#  [97, 1, 'mean'],
#  [97, 1, 'median'],
#  [98, 1, 'persist'],
#  [98, 1, 'mean'],
#  [98, 1, 'median'],
#  [99, 1, 'persist'],
#  [99, 1, 'mean'],
#  [99, 1, 'median'],
#  [100, 1, 'persist'],
#  [100, 1, 'mean'],
#  [100, 1, 'median'],
#  [101, 1, 'persist'],
#  [101, 1, 'mean'],
#  [101, 1, 'median'],
#  [102, 1, 'persist'],
#  [102, 1, 'mean'],
#  [102, 1, 'median'],
#  [103, 1, 'persist'],
#  [103, 1, 'mean'],
#  [103, 1, 'median'],
#  [104, 1, 'persist'],
#  [104, 1, 'mean'],
#  [104, 1, 'median'],
#  [105, 1, 'persist'],
#  [105, 1, 'mean'],
#  [105, 1, 'median'],
#  [106, 1, 'persist'],
#  [106, 1, 'mean'],
#  [106, 1, 'median'],
#  [107, 1, 'persist'],
#  [107, 1, 'mean'],
#  [107, 1, 'median'],
#  [108, 1, 'persist'],
#  [108, 1, 'mean'],
#  [108, 1, 'median'],
#  [109, 1, 'persist'],
#  [109, 1, 'mean'],
#  [109, 1, 'median'],
#  [110, 1, 'persist'],
#  [110, 1, 'mean'],
#  [110, 1, 'median'],
#  [111, 1, 'persist'],
#  [111, 1, 'mean'],
#  [111, 1, 'median'],
#  [112, 1, 'persist'],
#  [112, 1, 'mean'],
#  [112, 1, 'median'],
#  [113, 1, 'persist'],
#  [113, 1, 'mean'],
#  [113, 1, 'median'],
#  [114, 1, 'persist'],
#  [114, 1, 'mean'],
#  [114, 1, 'median'],
#  [115, 1, 'persist'],
#  [115, 1, 'mean'],
#  [115, 1, 'median'],
#  [116, 1, 'persist'],
#  [116, 1, 'mean'],
#  [116, 1, 'median'],
#  [117, 1, 'persist'],
#  [117, 1, 'mean'],
#  [117, 1, 'median'],
#  [118, 1, 'persist'],
#  [118, 1, 'mean'],
#  [118, 1, 'median'],
#  [119, 1, 'persist'],
#  [119, 1, 'mean'],
#  [119, 1, 'median'],
#  [120, 1, 'persist'],
#  [120, 1, 'mean'],
#  [120, 1, 'median'],
#  [121, 1, 'persist'],
#  [121, 1, 'mean'],
#  [121, 1, 'median'],
#  [122, 1, 'persist'],
#  [122, 1, 'mean'],
#  [122, 1, 'median'],
#  [123, 1, 'persist'],
#  [123, 1, 'mean'],
#  [123, 1, 'median'],
#  [124, 1, 'persist'],
#  [124, 1, 'mean'],
#  [124, 1, 'median'],
#  [125, 1, 'persist'],
#  [125, 1, 'mean'],
#  [125, 1, 'median'],
#  [126, 1, 'persist'],
#  [126, 1, 'mean'],
#  [126, 1, 'median'],
#  [127, 1, 'persist'],
#  [127, 1, 'mean'],
#  [127, 1, 'median'],
#  [128, 1, 'persist'],
#  [128, 1, 'mean'],
#  [128, 1, 'median'],
#  [129, 1, 'persist'],
#  [129, 1, 'mean'],
#  [129, 1, 'median'],
#  [130, 1, 'persist'],
#  [130, 1, 'mean'],
#  [130, 1, 'median'],
#  [131, 1, 'persist'],
#  [131, 1, 'mean'],
#  [131, 1, 'median'],
#  [132, 1, 'persist'],
#  [132, 1, 'mean'],
#  [132, 1, 'median'],
#  [133, 1, 'persist'],
#  [133, 1, 'mean'],
#  [133, 1, 'median'],
#  [134, 1, 'persist'],
#  [134, 1, 'mean'],
#  [134, 1, 'median'],
#  [135, 1, 'persist'],
#  [135, 1, 'mean'],
#  [135, 1, 'median'],
#  [136, 1, 'persist'],
#  [136, 1, 'mean'],
#  [136, 1, 'median'],
#  [137, 1, 'persist'],
#  [137, 1, 'mean'],
#  [137, 1, 'median'],
#  [138, 1, 'persist'],
#  [138, 1, 'mean'],
#  [138, 1, 'median'],
#  [139, 1, 'persist'],
#  [139, 1, 'mean'],
#  [139, 1, 'median'],
#  [140, 1, 'persist'],
#  [140, 1, 'mean'],
#  [140, 1, 'median'],
#  [141, 1, 'persist'],
#  [141, 1, 'mean'],
#  [141, 1, 'median'],
#  [142, 1, 'persist'],
#  [142, 1, 'mean'],
#  [142, 1, 'median'],
#  [143, 1, 'persist'],
#  [143, 1, 'mean'],
#  [143, 1, 'median'],
#  [144, 1, 'persist'],
#  [144, 1, 'mean'],
#  [144, 1, 'median'],
#  [145, 1, 'persist'],
#  [145, 1, 'mean'],
#  [145, 1, 'median'],
#  [146, 1, 'persist'],
#  [146, 1, 'mean'],
#  [146, 1, 'median'],
#  [147, 1, 'persist'],
#  [147, 1, 'mean'],
#  [147, 1, 'median'],
#  [148, 1, 'persist'],
#  [148, 1, 'mean'],
#  [148, 1, 'median'],
#  [149, 1, 'persist'],
#  [149, 1, 'mean'],
#  [149, 1, 'median'],
#  [150, 1, 'persist'],
#  [150, 1, 'mean'],
#  [150, 1, 'median'],
#  [151, 1, 'persist'],
#  [151, 1, 'mean'],
#  [151, 1, 'median'],
#  [152, 1, 'persist'],
#  [152, 1, 'mean'],
#  [152, 1, 'median'],
#  [153, 1, 'persist'],
#  [153, 1, 'mean'],
#  [153, 1, 'median'],
#  [154, 1, 'persist'],
#  [154, 1, 'mean'],
#  [154, 1, 'median'],
#  [155, 1, 'persist'],
#  [155, 1, 'mean'],
#  [155, 1, 'median'],
#  [156, 1, 'persist'],
#  [156, 1, 'mean'],
#  [156, 1, 'median'],
#  [157, 1, 'persist'],
#  [157, 1, 'mean'],
#  [157, 1, 'median'],
#  [158, 1, 'persist'],
#  [158, 1, 'mean'],
#  [158, 1, 'median'],
#  [159, 1, 'persist'],
#  [159, 1, 'mean'],
#  [159, 1, 'median'],
#  [160, 1, 'persist'],
#  [160, 1, 'mean'],
#  [160, 1, 'median'],
#  [161, 1, 'persist'],
#  [161, 1, 'mean'],
#  [161, 1, 'median'],
#  [162, 1, 'persist'],
#  [162, 1, 'mean'],
#  [162, 1, 'median'],
#  [163, 1, 'persist'],
#  [163, 1, 'mean'],
#  [163, 1, 'median'],
#  [164, 1, 'persist'],
#  [164, 1, 'mean'],
#  [164, 1, 'median'],
#  [165, 1, 'persist'],
#  [165, 1, 'mean'],
#  [165, 1, 'median'],
#  [166, 1, 'persist'],
#  [166, 1, 'mean'],
#  [166, 1, 'median'],
#  [167, 1, 'persist'],
#  [167, 1, 'mean'],
#  [167, 1, 'median'],
#  [168, 1, 'persist'],
#  [168, 1, 'mean'],
#  [168, 1, 'median'],
#  [169, 1, 'persist'],
#  [169, 1, 'mean'],
#  [169, 1, 'median'],
#  [170, 1, 'persist'],
#  [170, 1, 'mean'],
#  [170, 1, 'median'],
#  [171, 1, 'persist'],
#  [171, 1, 'mean'],
#  [171, 1, 'median'],
#  [172, 1, 'persist'],
#  [172, 1, 'mean'],
#  [172, 1, 'median'],
#  [173, 1, 'persist'],
#  [173, 1, 'mean'],
#  [173, 1, 'median'],
#  [174, 1, 'persist'],
#  [174, 1, 'mean'],
#  [174, 1, 'median'],
#  [175, 1, 'persist'],
#  [175, 1, 'mean'],
#  [175, 1, 'median'],
#  [176, 1, 'persist'],
#  [176, 1, 'mean'],
#  [176, 1, 'median'],
#  [177, 1, 'persist'],
#  [177, 1, 'mean'],
#  [177, 1, 'median'],
#  [178, 1, 'persist'],
#  [178, 1, 'mean'],
#  [178, 1, 'median'],
#  [179, 1, 'persist'],
#  [179, 1, 'mean'],
#  [179, 1, 'median'],
#  [180, 1, 'persist'],
#  [180, 1, 'mean'],
#  [180, 1, 'median'],
#  [181, 1, 'persist'],
#  [181, 1, 'mean'],
#  [181, 1, 'median'],
#  [182, 1, 'persist'],
#  [182, 1, 'mean'],
#  [182, 1, 'median'],
#  [183, 1, 'persist'],
#  [183, 1, 'mean'],
#  [183, 1, 'median'],
#  [184, 1, 'persist'],
#  [184, 1, 'mean'],
#  [184, 1, 'median'],
#  [185, 1, 'persist'],
#  [185, 1, 'mean'],
#  [185, 1, 'median'],
#  [186, 1, 'persist'],
#  [186, 1, 'mean'],
#  [186, 1, 'median'],
#  [187, 1, 'persist'],
#  [187, 1, 'mean'],
#  [187, 1, 'median'],
#  [188, 1, 'persist'],
#  [188, 1, 'mean'],
#  [188, 1, 'median'],
#  [189, 1, 'persist'],
#  [189, 1, 'mean'],
#  [189, 1, 'median'],
#  [190, 1, 'persist'],
#  [190, 1, 'mean'],
#  [190, 1, 'median'],
#  [191, 1, 'persist'],
#  [191, 1, 'mean'],
#  [191, 1, 'median'],
#  [192, 1, 'persist'],
#  [192, 1, 'mean'],
#  [192, 1, 'median'],
#  [193, 1, 'persist'],
#  [193, 1, 'mean'],
#  [193, 1, 'median'],
#  [194, 1, 'persist'],
#  [194, 1, 'mean'],
#  [194, 1, 'median'],
#  [195, 1, 'persist'],
#  [195, 1, 'mean'],
#  [195, 1, 'median'],
#  [196, 1, 'persist'],
#  [196, 1, 'mean'],
#  [196, 1, 'median'],
#  [197, 1, 'persist'],
#  [197, 1, 'mean'],
#  [197, 1, 'median'],
#  [198, 1, 'persist'],
#  [198, 1, 'mean'],
#  [198, 1, 'median'],
#  [199, 1, 'persist'],
#  [199, 1, 'mean'],
#  [199, 1, 'median'],
#  [200, 1, 'persist'],
#  [200, 1, 'mean'],
#  [200, 1, 'median']]

# %%
# grid search
scores = grid_search(data, cfg_list, n_test)
print('done')
# Out:
#  > Model[[1, 1, 'persist']] 8.722
#  > Model[[2, 1, 'persist']] 9.284
#  > Model[[2, 1, 'mean']] 7.884
#  > Model[[2, 1, 'median']] 7.884
#  > Model[[3, 1, 'persist']] 9.320
#  > Model[[3, 1, 'mean']] 7.518
#  > Model[[3, 1, 'median']] 7.324
#  > Model[[4, 1, 'persist']] 9.249
#  > Model[[4, 1, 'mean']] 7.290
#  > Model[[4, 1, 'median']] 7.217
#  > Model[[5, 1, 'persist']] 9.415
#  > Model[[5, 1, 'mean']] 7.204
#  > Model[[5, 1, 'median']] 7.337
#  > Model[[6, 1, 'persist']] 9.737
#  > Model[[6, 1, 'mean']] 7.222
#  > Model[[6, 1, 'median']] 7.230
#  > Model[[7, 1, 'persist']] 8.791
#  > Model[[7, 1, 'mean']] 7.042
#  > Model[[7, 1, 'median']] 7.340
#  > Model[[8, 1, 'persist']] 10.172
#  > Model[[8, 1, 'mean']] 7.140
#  > Model[[8, 1, 'median']] 7.331
#  > Model[[9, 1, 'persist']] 10.175
#  > Model[[9, 1, 'mean']] 7.200
#  > Model[[9, 1, 'median']] 7.302
#  > Model[[10, 1, 'persist']] 9.956
#  > Model[[10, 1, 'mean']] 7.209
#  > Model[[10, 1, 'median']] 7.349
#  > Model[[11, 1, 'persist']] 9.873
#  > Model[[11, 1, 'mean']] 7.201
#  > Model[[11, 1, 'median']] 7.290
#  > Model[[12, 1, 'persist']] 10.334
#  > Model[[12, 1, 'mean']] 7.246
#  > Model[[12, 1, 'median']] 7.360
#  > Model[[13, 1, 'persist']] 10.020
#  > Model[[13, 1, 'mean']] 7.238
#  > Model[[13, 1, 'median']] 7.426
#  > Model[[14, 1, 'persist']] 9.392
#  > Model[[14, 1, 'mean']] 7.170
#  > Model[[14, 1, 'median']] 7.209
#  > Model[[15, 1, 'persist']] 9.634
#  > Model[[15, 1, 'mean']] 7.136
#  > Model[[15, 1, 'median']] 7.320
#  > Model[[16, 1, 'persist']] 9.891
#  > Model[[16, 1, 'mean']] 7.130
#  > Model[[16, 1, 'median']] 7.269
#  > Model[[17, 1, 'persist']] 9.813
#  > Model[[17, 1, 'mean']] 7.118
#  > Model[[17, 1, 'median']] 7.290
#  > Model[[18, 1, 'persist']] 9.611
#  > Model[[18, 1, 'mean']] 7.093
#  > Model[[18, 1, 'median']] 7.247
#  > Model[[19, 1, 'persist']] 9.656
#  > Model[[19, 1, 'mean']] 7.076
#  > Model[[19, 1, 'median']] 7.273
#  > Model[[20, 1, 'persist']] 9.198
#  > Model[[20, 1, 'mean']] 7.026
#  > Model[[20, 1, 'median']] 7.235
#  > Model[[21, 1, 'persist']] 8.679
#  > Model[[21, 1, 'mean']] 6.952
#  > Model[[21, 1, 'median']] 7.121
#  > Model[[22, 1, 'persist']] 9.411
#  > Model[[22, 1, 'mean']] 6.930
#  > Model[[22, 1, 'median']] 7.104
#  > Model[[23, 1, 'persist']] 9.759
#  > Model[[23, 1, 'mean']] 6.932
#  > Model[[23, 1, 'median']] 7.096
#  > Model[[24, 1, 'persist']] 10.065
#  > Model[[24, 1, 'mean']] 6.952
#  > Model[[24, 1, 'median']] 7.099
#  > Model[[25, 1, 'persist']] 9.973
#  > Model[[25, 1, 'mean']] 6.963
#  > Model[[25, 1, 'median']] 7.106
#  > Model[[26, 1, 'persist']] 10.258
#  > Model[[26, 1, 'mean']] 6.988
#  > Model[[26, 1, 'median']] 7.117
#  > Model[[27, 1, 'persist']] 10.059
#  > Model[[27, 1, 'mean']] 7.000
#  > Model[[27, 1, 'median']] 7.095
#  > Model[[28, 1, 'persist']] 9.473
#  > Model[[28, 1, 'mean']] 6.981
#  > Model[[28, 1, 'median']] 7.111
#  > Model[[29, 1, 'persist']] 10.185
#  > Model[[29, 1, 'mean']] 6.999
#  > Model[[29, 1, 'median']] 7.160
#  > Model[[30, 1, 'persist']] 10.326
#  > Model[[30, 1, 'mean']] 7.023
#  > Model[[30, 1, 'median']] 7.140
#  > Model[[31, 1, 'persist']] 10.180
#  > Model[[31, 1, 'mean']] 7.038
#  > Model[[31, 1, 'median']] 7.106
#  > Model[[32, 1, 'persist']] 10.292
#  > Model[[32, 1, 'mean']] 7.057
#  > Model[[32, 1, 'median']] 7.127
#  > Model[[33, 1, 'persist']] 10.620
#  > Model[[33, 1, 'mean']] 7.087
#  > Model[[33, 1, 'median']] 7.171
#  > Model[[34, 1, 'persist']] 10.438
#  > Model[[34, 1, 'mean']] 7.106
#  > Model[[34, 1, 'median']] 7.159
#  > Model[[35, 1, 'persist']] 10.294
#  > Model[[35, 1, 'mean']] 7.117
#  > Model[[35, 1, 'median']] 7.156
#  > Model[[36, 1, 'persist']] 9.881
#  > Model[[36, 1, 'mean']] 7.112
#  > Model[[36, 1, 'median']] 7.174
#  > Model[[37, 1, 'persist']] 9.889
#  > Model[[37, 1, 'mean']] 7.107
#  > Model[[37, 1, 'median']] 7.219
#  > Model[[38, 1, 'persist']] 9.825
#  > Model[[38, 1, 'mean']] 7.100
#  > Model[[38, 1, 'median']] 7.152
#  > Model[[39, 1, 'persist']] 9.637
#  > Model[[39, 1, 'mean']] 7.088
#  > Model[[39, 1, 'median']] 7.167
#  > Model[[40, 1, 'persist']] 10.139
#  > Model[[40, 1, 'mean']] 7.095
#  > Model[[40, 1, 'median']] 7.128
#  > Model[[41, 1, 'persist']] 10.014
#  > Model[[41, 1, 'mean']] 7.097
#  > Model[[41, 1, 'median']] 7.112
#  > Model[[42, 1, 'persist']] 10.006
#  > Model[[42, 1, 'mean']] 7.098
#  > Model[[42, 1, 'median']] 7.138
#  > Model[[43, 1, 'persist']] 9.659
#  > Model[[43, 1, 'mean']] 7.087
#  > Model[[43, 1, 'median']] 7.130
#  > Model[[44, 1, 'persist']] 9.726
#  > Model[[44, 1, 'mean']] 7.078
#  > Model[[44, 1, 'median']] 7.101
#  > Model[[45, 1, 'persist']] 9.666
#  > Model[[45, 1, 'mean']] 7.069
#  > Model[[45, 1, 'median']] 7.065
#  > Model[[46, 1, 'persist']] 10.208
#  > Model[[46, 1, 'mean']] 7.077
#  > Model[[46, 1, 'median']] 7.080
#  > Model[[47, 1, 'persist']] 10.650
#  > Model[[47, 1, 'mean']] 7.097
#  > Model[[47, 1, 'median']] 7.098
#  > Model[[48, 1, 'persist']] 10.373
#  > Model[[48, 1, 'mean']] 7.109
#  > Model[[48, 1, 'median']] 7.094
#  > Model[[49, 1, 'persist']] 9.927
#  > Model[[49, 1, 'mean']] 7.107
#  > Model[[49, 1, 'median']] 7.096
#  > Model[[50, 1, 'persist']] 10.156
#  > Model[[50, 1, 'mean']] 7.111
#  > Model[[50, 1, 'median']] 7.106
#  > Model[[51, 1, 'persist']] 10.079
#  > Model[[51, 1, 'mean']] 7.113
#  > Model[[51, 1, 'median']] 7.143
#  > Model[[52, 1, 'persist']] 10.579
#  > Model[[52, 1, 'mean']] 7.129
#  > Model[[52, 1, 'median']] 7.155
#  > Model[[53, 1, 'persist']] 10.020
#  > Model[[53, 1, 'mean']] 7.128
#  > Model[[53, 1, 'median']] 7.162
#  > Model[[54, 1, 'persist']] 10.649
#  > Model[[54, 1, 'mean']] 7.144
#  > Model[[54, 1, 'median']] 7.119
#  > Model[[55, 1, 'persist']] 10.591
#  > Model[[55, 1, 'mean']] 7.158
#  > Model[[55, 1, 'median']] 7.115
#  > Model[[56, 1, 'persist']] 9.874
#  > Model[[56, 1, 'mean']] 7.153
#  > Model[[56, 1, 'median']] 7.105
#  > Model[[57, 1, 'persist']] 9.792
#  > Model[[57, 1, 'mean']] 7.148
#  > Model[[57, 1, 'median']] 7.077
#  > Model[[58, 1, 'persist']] 9.741
#  > Model[[58, 1, 'mean']] 7.142
#  > Model[[58, 1, 'median']] 7.086
#  > Model[[59, 1, 'persist']] 10.050
#  > Model[[59, 1, 'mean']] 7.144
#  > Model[[59, 1, 'median']] 7.093
#  > Model[[60, 1, 'persist']] 9.473
#  > Model[[60, 1, 'mean']] 7.131
#  > Model[[60, 1, 'median']] 7.074
#  > Model[[61, 1, 'persist']] 9.952
#  > Model[[61, 1, 'mean']] 7.130
#  > Model[[61, 1, 'median']] 7.088
#  > Model[[62, 1, 'persist']] 10.374
#  > Model[[62, 1, 'mean']] 7.138
#  > Model[[62, 1, 'median']] 7.068
#  > Model[[63, 1, 'persist']] 10.409
#  > Model[[63, 1, 'mean']] 7.146
#  > Model[[63, 1, 'median']] 7.087
#  > Model[[64, 1, 'persist']] 9.479
#  > Model[[64, 1, 'mean']] 7.132
#  > Model[[64, 1, 'median']] 7.063
#  > Model[[65, 1, 'persist']] 10.299
#  > Model[[65, 1, 'mean']] 7.136
#  > Model[[65, 1, 'median']] 7.077
#  > Model[[66, 1, 'persist']] 9.995
#  > Model[[66, 1, 'mean']] 7.135
#  > Model[[66, 1, 'median']] 7.074
#  > Model[[67, 1, 'persist']] 10.082
#  > Model[[67, 1, 'mean']] 7.136
#  > Model[[67, 1, 'median']] 7.084
#  > Model[[68, 1, 'persist']] 10.359
#  > Model[[68, 1, 'mean']] 7.143
#  > Model[[68, 1, 'median']] 7.108
#  > Model[[69, 1, 'persist']] 10.415
#  > Model[[69, 1, 'mean']] 7.151
#  > Model[[69, 1, 'median']] 7.107
#  > Model[[70, 1, 'persist']] 10.970
#  > Model[[70, 1, 'mean']] 7.171
#  > Model[[70, 1, 'median']] 7.126
#  > Model[[71, 1, 'persist']] 10.049
#  > Model[[71, 1, 'mean']] 7.170
#  > Model[[71, 1, 'median']] 7.077
#  > Model[[72, 1, 'persist']] 10.613
#  > Model[[72, 1, 'mean']] 7.181
#  > Model[[72, 1, 'median']] 7.108
#  > Model[[73, 1, 'persist']] 10.521
#  > Model[[73, 1, 'mean']] 7.188
#  > Model[[73, 1, 'median']] 7.095
#  > Model[[74, 1, 'persist']] 10.384
#  > Model[[74, 1, 'mean']] 7.192
#  > Model[[74, 1, 'median']] 7.108
#  > Model[[75, 1, 'persist']] 10.332
#  > Model[[75, 1, 'mean']] 7.195
#  > Model[[75, 1, 'median']] 7.129
#  > Model[[76, 1, 'persist']] 9.980
#  > Model[[76, 1, 'mean']] 7.192
#  > Model[[76, 1, 'median']] 7.122
#  > Model[[77, 1, 'persist']] 10.734
#  > Model[[77, 1, 'mean']] 7.202
#  > Model[[77, 1, 'median']] 7.148
#  > Model[[78, 1, 'persist']] 10.221
#  > Model[[78, 1, 'mean']] 7.203
#  > Model[[78, 1, 'median']] 7.132
#  > Model[[79, 1, 'persist']] 10.741
#  > Model[[79, 1, 'mean']] 7.213
#  > Model[[79, 1, 'median']] 7.130
#  > Model[[80, 1, 'persist']] 11.225
#  > Model[[80, 1, 'mean']] 7.233
#  > Model[[80, 1, 'median']] 7.133
#  > Model[[81, 1, 'persist']] 10.456
#  > Model[[81, 1, 'mean']] 7.237
#  > Model[[81, 1, 'median']] 7.136
#  > Model[[82, 1, 'persist']] 10.026
#  > Model[[82, 1, 'mean']] 7.232
#  > Model[[82, 1, 'median']] 7.139
#  > Model[[83, 1, 'persist']] 10.253
#  > Model[[83, 1, 'mean']] 7.231
#  > Model[[83, 1, 'median']] 7.150
#  > Model[[84, 1, 'persist']] 10.515
#  > Model[[84, 1, 'mean']] 7.235
#  > Model[[84, 1, 'median']] 7.152
#  > Model[[85, 1, 'persist']] 10.452
#  > Model[[85, 1, 'mean']] 7.237
#  > Model[[85, 1, 'median']] 7.157
#  > Model[[86, 1, 'persist']] 10.627
#  > Model[[86, 1, 'mean']] 7.243
#  > Model[[86, 1, 'median']] 7.176
#  > Model[[87, 1, 'persist']] 10.571
#  > Model[[87, 1, 'mean']] 7.247
#  > Model[[87, 1, 'median']] 7.164
#  > Model[[88, 1, 'persist']] 10.274
#  > Model[[88, 1, 'mean']] 7.245
#  > Model[[88, 1, 'median']] 7.177
#  > Model[[89, 1, 'persist']] 9.652
#  > Model[[89, 1, 'mean']] 7.234
#  > Model[[89, 1, 'median']] 7.185
#  > Model[[90, 1, 'persist']] 10.493
#  > Model[[90, 1, 'mean']] 7.236
#  > Model[[90, 1, 'median']] 7.198
#  > Model[[91, 1, 'persist']] 10.736
#  > Model[[91, 1, 'mean']] 7.242
#  > Model[[91, 1, 'median']] 7.207
#  > Model[[92, 1, 'persist']] 10.429
#  > Model[[92, 1, 'mean']] 7.244
#  > Model[[92, 1, 'median']] 7.194
#  > Model[[93, 1, 'persist']] 10.731
#  > Model[[93, 1, 'mean']] 7.250
#  > Model[[93, 1, 'median']] 7.194
#  > Model[[94, 1, 'persist']] 10.570
#  > Model[[94, 1, 'mean']] 7.254
#  > Model[[94, 1, 'median']] 7.202
#  > Model[[95, 1, 'persist']] 10.660
#  > Model[[95, 1, 'mean']] 7.259
#  > Model[[95, 1, 'median']] 7.217
#  > Model[[96, 1, 'persist']] 10.610
#  > Model[[96, 1, 'mean']] 7.263
#  > Model[[96, 1, 'median']] 7.221
#  > Model[[97, 1, 'persist']] 10.620
#  > Model[[97, 1, 'mean']] 7.267
#  > Model[[97, 1, 'median']] 7.216
#  > Model[[98, 1, 'persist']] 10.659
#  > Model[[98, 1, 'mean']] 7.271
#  > Model[[98, 1, 'median']] 7.225
#  > Model[[99, 1, 'persist']] 10.747
#  > Model[[99, 1, 'mean']] 7.276
#  > Model[[99, 1, 'median']] 7.230
#  > Model[[100, 1, 'persist']] 10.653
#  > Model[[100, 1, 'mean']] 7.283
#  > Model[[100, 1, 'median']] 7.247
#  > Model[[101, 1, 'persist']] 10.724
#  > Model[[101, 1, 'mean']] 7.291
#  > Model[[101, 1, 'median']] 7.263
#  > Model[[102, 1, 'persist']] 10.198
#  > Model[[102, 1, 'mean']] 7.292
#  > Model[[102, 1, 'median']] 7.274
#  > Model[[103, 1, 'persist']] 10.024
#  > Model[[103, 1, 'mean']] 7.291
#  > Model[[103, 1, 'median']] 7.285
#  > Model[[104, 1, 'persist']] 10.054
#  > Model[[104, 1, 'mean']] 7.291
#  > Model[[104, 1, 'median']] 7.293
#  > Model[[105, 1, 'persist']] 10.159
#  > Model[[105, 1, 'mean']] 7.292
#  > Model[[105, 1, 'median']] 7.306
#  > Model[[106, 1, 'persist']] 10.531
#  > Model[[106, 1, 'mean']] 7.298
#  > Model[[106, 1, 'median']] 7.301
#  > Model[[107, 1, 'persist']] 10.545
#  > Model[[107, 1, 'mean']] 7.304
#  > Model[[107, 1, 'median']] 7.306
#  > Model[[108, 1, 'persist']] 11.023
#  > Model[[108, 1, 'mean']] 7.317
#  > Model[[108, 1, 'median']] 7.317
#  > Model[[109, 1, 'persist']] 9.861
#  > Model[[109, 1, 'mean']] 7.314
#  > Model[[109, 1, 'median']] 7.337
#  > Model[[110, 1, 'persist']] 9.877
#  > Model[[110, 1, 'mean']] 7.312
#  > Model[[110, 1, 'median']] 7.332
#  > Model[[111, 1, 'persist']] 10.482
#  > Model[[111, 1, 'mean']] 7.317
#  > Model[[111, 1, 'median']] 7.353
#  > Model[[112, 1, 'persist']] 10.381
#  > Model[[112, 1, 'mean']] 7.321
#  > Model[[112, 1, 'median']] 7.342
#  > Model[[113, 1, 'persist']] 10.697
#  > Model[[113, 1, 'mean']] 7.329
#  > Model[[113, 1, 'median']] 7.353
#  > Model[[114, 1, 'persist']] 10.117
#  > Model[[114, 1, 'mean']] 7.329
#  > Model[[114, 1, 'median']] 7.361
#  > Model[[115, 1, 'persist']] 10.476
#  > Model[[115, 1, 'mean']] 7.334
#  > Model[[115, 1, 'median']] 7.357
#  > Model[[116, 1, 'persist']] 10.733
#  > Model[[116, 1, 'mean']] 7.341
#  > Model[[116, 1, 'median']] 7.359
#  > Model[[117, 1, 'persist']] 10.080
#  > Model[[117, 1, 'mean']] 7.340
#  > Model[[117, 1, 'median']] 7.367
#  > Model[[118, 1, 'persist']] 10.766
#  > Model[[118, 1, 'mean']] 7.348
#  > Model[[118, 1, 'median']] 7.374
#  > Model[[119, 1, 'persist']] 10.496
#  > Model[[119, 1, 'mean']] 7.352
#  > Model[[119, 1, 'median']] 7.376
#  > Model[[120, 1, 'persist']] 10.013
#  > Model[[120, 1, 'mean']] 7.350
#  > Model[[120, 1, 'median']] 7.386
#  > Model[[121, 1, 'persist']] 9.933
#  > Model[[121, 1, 'mean']] 7.349
#  > Model[[121, 1, 'median']] 7.401
#  > Model[[122, 1, 'persist']] 10.464
#  > Model[[122, 1, 'mean']] 7.354
#  > Model[[122, 1, 'median']] 7.409
#  > Model[[123, 1, 'persist']] 10.381
#  > Model[[123, 1, 'mean']] 7.358
#  > Model[[123, 1, 'median']] 7.428
#  > Model[[124, 1, 'persist']] 9.977
#  > Model[[124, 1, 'mean']] 7.358
#  > Model[[124, 1, 'median']] 7.416
#  > Model[[125, 1, 'persist']] 9.778
#  > Model[[125, 1, 'mean']] 7.355
#  > Model[[125, 1, 'median']] 7.439
#  > Model[[126, 1, 'persist']] 9.855
#  > Model[[126, 1, 'mean']] 7.353
#  > Model[[126, 1, 'median']] 7.425
#  > Model[[127, 1, 'persist']] 10.305
#  > Model[[127, 1, 'mean']] 7.356
#  > Model[[127, 1, 'median']] 7.444
#  > Model[[128, 1, 'persist']] 10.568
#  > Model[[128, 1, 'mean']] 7.361
#  > Model[[128, 1, 'median']] 7.440
#  > Model[[129, 1, 'persist']] 10.739
#  > Model[[129, 1, 'mean']] 7.368
#  > Model[[129, 1, 'median']] 7.462
#  > Model[[130, 1, 'persist']] 10.703
#  > Model[[130, 1, 'mean']] 7.374
#  > Model[[130, 1, 'median']] 7.442
#  > Model[[131, 1, 'persist']] 10.131
#  > Model[[131, 1, 'mean']] 7.374
#  > Model[[131, 1, 'median']] 7.458
#  > Model[[132, 1, 'persist']] 9.665
#  > Model[[132, 1, 'mean']] 7.370
#  > Model[[132, 1, 'median']] 7.440
#  > Model[[133, 1, 'persist']] 9.984
#  > Model[[133, 1, 'mean']] 7.368
#  > Model[[133, 1, 'median']] 7.437
#  > Model[[134, 1, 'persist']] 10.576
#  > Model[[134, 1, 'mean']] 7.373
#  > Model[[134, 1, 'median']] 7.425
#  > Model[[135, 1, 'persist']] 10.642
#  > Model[[135, 1, 'mean']] 7.378
#  > Model[[135, 1, 'median']] 7.426
#  > Model[[136, 1, 'persist']] 10.481
#  > Model[[136, 1, 'mean']] 7.381
#  > Model[[136, 1, 'median']] 7.431
#  > Model[[137, 1, 'persist']] 10.726
#  > Model[[137, 1, 'mean']] 7.388
#  > Model[[137, 1, 'median']] 7.435
#  > Model[[138, 1, 'persist']] 10.931
#  > Model[[138, 1, 'mean']] 7.396
#  > Model[[138, 1, 'median']] 7.451
#  > Model[[139, 1, 'persist']] 10.642
#  > Model[[139, 1, 'mean']] 7.400
#  > Model[[139, 1, 'median']] 7.468
#  > Model[[140, 1, 'persist']] 10.538
#  > Model[[140, 1, 'mean']] 7.404
#  > Model[[140, 1, 'median']] 7.463
#  > Model[[141, 1, 'persist']] 10.413
#  > Model[[141, 1, 'mean']] 7.406
#  > Model[[141, 1, 'median']] 7.452
#  > Model[[142, 1, 'persist']] 10.491
#  > Model[[142, 1, 'mean']] 7.408
#  > Model[[142, 1, 'median']] 7.468
#  > Model[[143, 1, 'persist']] 11.067
#  > Model[[143, 1, 'mean']] 7.416
#  > Model[[143, 1, 'median']] 7.490
#  > Model[[144, 1, 'persist']] 10.980
#  > Model[[144, 1, 'mean']] 7.424
#  > Model[[144, 1, 'median']] 7.496
#  > Model[[145, 1, 'persist']] 10.476
#  > Model[[145, 1, 'mean']] 7.425
#  > Model[[145, 1, 'median']] 7.506
#  > Model[[146, 1, 'persist']] 9.801
#  > Model[[146, 1, 'mean']] 7.421
#  > Model[[146, 1, 'median']] 7.496
#  > Model[[147, 1, 'persist']] 9.540
#  > Model[[147, 1, 'mean']] 7.415
#  > Model[[147, 1, 'median']] 7.507
#  > Model[[148, 1, 'persist']] 10.267
#  > Model[[148, 1, 'mean']] 7.415
#  > Model[[148, 1, 'median']] 7.502
#  > Model[[149, 1, 'persist']] 10.812
#  > Model[[149, 1, 'mean']] 7.421
#  > Model[[149, 1, 'median']] 7.516
#  > Model[[150, 1, 'persist']] 10.813
#  > Model[[150, 1, 'mean']] 7.427
#  > Model[[150, 1, 'median']] 7.520
#  > Model[[151, 1, 'persist']] 10.443
#  > Model[[151, 1, 'mean']] 7.429
#  > Model[[151, 1, 'median']] 7.518
#  > Model[[152, 1, 'persist']] 10.189
#  > Model[[152, 1, 'mean']] 7.429
#  > Model[[152, 1, 'median']] 7.498
#  > Model[[153, 1, 'persist']] 10.180
#  > Model[[153, 1, 'mean']] 7.429
#  > Model[[153, 1, 'median']] 7.489
#  > Model[[154, 1, 'persist']] 10.223
#  > Model[[154, 1, 'mean']] 7.429
#  > Model[[154, 1, 'median']] 7.491
#  > Model[[155, 1, 'persist']] 10.380
#  > Model[[155, 1, 'mean']] 7.430
#  > Model[[155, 1, 'median']] 7.492
#  > Model[[156, 1, 'persist']] 10.690
#  > Model[[156, 1, 'mean']] 7.435
#  > Model[[156, 1, 'median']] 7.506
#  > Model[[157, 1, 'persist']] 11.226
#  > Model[[157, 1, 'mean']] 7.443
#  > Model[[157, 1, 'median']] 7.518
#  > Model[[158, 1, 'persist']] 11.135
#  > Model[[158, 1, 'mean']] 7.451
#  > Model[[158, 1, 'median']] 7.521
#  > Model[[159, 1, 'persist']] 11.040
#  > Model[[159, 1, 'mean']] 7.458
#  > Model[[159, 1, 'median']] 7.541
#  > Model[[160, 1, 'persist']] 10.574
#  > Model[[160, 1, 'mean']] 7.460
#  > Model[[160, 1, 'median']] 7.548
#  > Model[[161, 1, 'persist']] 10.855
#  > Model[[161, 1, 'mean']] 7.465
#  > Model[[161, 1, 'median']] 7.563
#  > Model[[162, 1, 'persist']] 10.597
#  > Model[[162, 1, 'mean']] 7.467
#  > Model[[162, 1, 'median']] 7.559
#  > Model[[163, 1, 'persist']] 10.031
#  > Model[[163, 1, 'mean']] 7.464
#  > Model[[163, 1, 'median']] 7.570
#  > Model[[164, 1, 'persist']] 10.966
#  > Model[[164, 1, 'mean']] 7.469
#  > Model[[164, 1, 'median']] 7.579
#  > Model[[165, 1, 'persist']] 10.873
#  > Model[[165, 1, 'mean']] 7.473
#  > Model[[165, 1, 'median']] 7.577
#  > Model[[166, 1, 'persist']] 10.527
#  > Model[[166, 1, 'mean']] 7.474
#  > Model[[166, 1, 'median']] 7.591
#  > Model[[167, 1, 'persist']] 10.323
#  > Model[[167, 1, 'mean']] 7.473
#  > Model[[167, 1, 'median']] 7.609
#  > Model[[168, 1, 'persist']] 10.855
#  > Model[[168, 1, 'mean']] 7.476
#  > Model[[168, 1, 'median']] 7.602
#  > Model[[169, 1, 'persist']] 11.029
#  > Model[[169, 1, 'mean']] 7.481
#  > Model[[169, 1, 'median']] 7.606
#  > Model[[170, 1, 'persist']] 10.879
#  > Model[[170, 1, 'mean']] 7.483
#  > Model[[170, 1, 'median']] 7.603
#  > Model[[171, 1, 'persist']] 11.084
#  > Model[[171, 1, 'mean']] 7.487
#  > Model[[171, 1, 'median']] 7.604
#  > Model[[172, 1, 'persist']] 10.951
#  > Model[[172, 1, 'mean']] 7.490
#  > Model[[172, 1, 'median']] 7.604
#  > Model[[173, 1, 'persist']] 10.494
#  > Model[[173, 1, 'mean']] 7.490
#  > Model[[173, 1, 'median']] 7.607
#  > Model[[174, 1, 'persist']] 10.701
#  > Model[[174, 1, 'mean']] 7.492
#  > Model[[174, 1, 'median']] 7.614
#  > Model[[175, 1, 'persist']] 10.434
#  > Model[[175, 1, 'mean']] 7.491
#  > Model[[175, 1, 'median']] 7.619
#  > Model[[176, 1, 'persist']] 10.538
#  > Model[[176, 1, 'mean']] 7.492
#  > Model[[176, 1, 'median']] 7.630
#  > Model[[177, 1, 'persist']] 11.211
#  > Model[[177, 1, 'mean']] 7.498
#  > Model[[177, 1, 'median']] 7.643
#  > Model[[178, 1, 'persist']] 10.845
#  > Model[[178, 1, 'mean']] 7.501
#  > Model[[178, 1, 'median']] 7.648
#  > Model[[179, 1, 'persist']] 11.156
#  > Model[[179, 1, 'mean']] 7.506
#  > Model[[179, 1, 'median']] 7.669
#  > Model[[180, 1, 'persist']] 11.156
#  > Model[[180, 1, 'mean']] 7.511
#  > Model[[180, 1, 'median']] 7.656
#  > Model[[181, 1, 'persist']] 10.707
#  > Model[[181, 1, 'mean']] 7.512
#  > Model[[181, 1, 'median']] 7.651
#  > Model[[182, 1, 'persist']] 10.871
#  > Model[[182, 1, 'mean']] 7.514
#  > Model[[182, 1, 'median']] 7.656
#  > Model[[183, 1, 'persist']] 10.603
#  > Model[[183, 1, 'mean']] 7.514
#  > Model[[183, 1, 'median']] 7.669
#  > Model[[184, 1, 'persist']] 10.866
#  > Model[[184, 1, 'mean']] 7.517
#  > Model[[184, 1, 'median']] 7.673
#  > Model[[185, 1, 'persist']] 10.957
#  > Model[[185, 1, 'mean']] 7.520
#  > Model[[185, 1, 'median']] 7.706
#  > Model[[186, 1, 'persist']] 10.927
#  > Model[[186, 1, 'mean']] 7.523
#  > Model[[186, 1, 'median']] 7.691
#  > Model[[187, 1, 'persist']] 11.137
#  > Model[[187, 1, 'mean']] 7.527
#  > Model[[187, 1, 'median']] 7.696
#  > Model[[188, 1, 'persist']] 10.952
#  > Model[[188, 1, 'mean']] 7.530
#  > Model[[188, 1, 'median']] 7.702
#  > Model[[189, 1, 'persist']] 10.956
#  > Model[[189, 1, 'mean']] 7.532
#  > Model[[189, 1, 'median']] 7.715
#  > Model[[190, 1, 'persist']] 10.707
#  > Model[[190, 1, 'mean']] 7.533
#  > Model[[190, 1, 'median']] 7.672
#  > Model[[191, 1, 'persist']] 11.038
#  > Model[[191, 1, 'mean']] 7.536
#  > Model[[191, 1, 'median']] 7.669
#  > Model[[192, 1, 'persist']] 11.158
#  > Model[[192, 1, 'mean']] 7.540
#  > Model[[192, 1, 'median']] 7.666
#  > Model[[193, 1, 'persist']] 11.013
#  > Model[[193, 1, 'mean']] 7.543
#  > Model[[193, 1, 'median']] 7.685
#  > Model[[194, 1, 'persist']] 10.558
#  > Model[[194, 1, 'mean']] 7.543
#  > Model[[194, 1, 'median']] 7.677
#  > Model[[195, 1, 'persist']] 10.906
#  > Model[[195, 1, 'mean']] 7.544
#  > Model[[195, 1, 'median']] 7.668
#  > Model[[196, 1, 'persist']] 10.489
#  > Model[[196, 1, 'mean']] 7.543
#  > Model[[196, 1, 'median']] 7.665
#  > Model[[197, 1, 'persist']] 10.475
#  > Model[[197, 1, 'mean']] 7.542
#  > Model[[197, 1, 'median']] 7.664
#  > Model[[198, 1, 'persist']] 11.364
#  > Model[[198, 1, 'mean']] 7.547
#  > Model[[198, 1, 'median']] 7.679
#  > Model[[199, 1, 'persist']] 10.963
#  > Model[[199, 1, 'mean']] 7.550
#  > Model[[199, 1, 'median']] 7.683
#  > Model[[200, 1, 'persist']] 10.849
#  > Model[[200, 1, 'mean']] 7.551
#  > Model[[200, 1, 'median']] 7.681
# done

# %%
# list top 3 configs
for cfg, error in scores[:3]:
    print(cfg, error)
# Out:
# [22, 1, 'mean'] 6.930411499775709
# [23, 1, 'mean'] 6.932293117115201
# [21, 1, 'mean'] 6.951918385845375
